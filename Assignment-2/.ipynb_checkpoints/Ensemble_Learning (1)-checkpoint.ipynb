# %% [markdown]
# **Name**- Prashant Singh
#
# **Enrolment Number**-SAU/CS/Mtech(CS)/2024/04
#
# **Course**-Mtech(CS)

# %%
import pandas as pd
import numpy as np

# %%
link="https://raw.githubusercontent.com/praShaanT11/AI-ML-For-Cybersecurity/refs/heads/main/cybersecurity_intrusion_data.csv"
data=pd.read_csv(link)

# %%
data.head()
# Out:
#   session_id  network_packet_size protocol_type  login_attempts  \
# 0  SID_00001                  599           TCP               4
# 1  SID_00002                  472           TCP               3
# 2  SID_00003                  629           TCP               3
# 3  SID_00004                  804           UDP               4
# 4  SID_00005                  453           TCP               5
#
#    session_duration encryption_used  ip_reputation_score  failed_logins  \
# 0        492.983263             DES             0.606818              1
# 1       1557.996461             DES             0.301569              0
# 2         75.044262             DES             0.739164              2
# 3        601.248835             DES             0.123267              0
# 4        532.540888             AES             0.054874              1
#
#   browser_type  unusual_time_access  attack_detected
# 0         Edge                    0                1
# ...

# %%
data.columns
# Out:
# Index(['session_id', 'network_packet_size', 'protocol_type', 'login_attempts',
#        'session_duration', 'encryption_used', 'ip_reputation_score',
#        'failed_logins', 'browser_type', 'unusual_time_access',
#        'attack_detected'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# session_id                0
# network_packet_size       0
# protocol_type             0
# login_attempts            0
# session_duration          0
# encryption_used        1966
# ip_reputation_score       0
# failed_logins             0
# browser_type              0
# unusual_time_access       0
# attack_detected           0
# dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data["attack_detected"].value_counts()
# Out:
# attack_detected
# 0    5273
# 1    4264
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='attack_detected', data=data)
plt.title('Distribution of Attack Detection')
plt.show()

# %%
plt.figure(figsize=(10, 8))
numerical_df = data.select_dtypes(include=np.number)  # Select only numerical columns
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
data.dtypes
# Out:
# session_id              object
# network_packet_size      int64
# protocol_type           object
# login_attempts           int64
# session_duration       float64
# encryption_used         object
# ip_reputation_score    float64
# failed_logins            int64
# browser_type            object
# unusual_time_access      int64
# attack_detected          int64
# dtype: object

# %%
data['protocol_type'].value_counts()
# Out:
# protocol_type
# TCP     6624
# UDP     2406
# ICMP     507
# Name: count, dtype: int64

# %%
data['browser_type'].value_counts()
# Out:
# browser_type
# Chrome     5137
# Firefox    1944
# Edge       1469
# Unknown     502
# Safari      485
# Name: count, dtype: int64

# %%
data['encryption_used'].value_counts()
# Out:
# encryption_used
# AES    4706
# DES    2865
# Name: count, dtype: int64

# %% [markdown]
# **Label Encoding the protocol type**
#
# tcp-->0
#
# udp-->1
#
# icmp-->2

# %%
data['protocol_type'] = data['protocol_type'].map({'TCP':0, 'UDP':1, 'ICMP':2})

# %% [markdown]
# **Label Encoding the browser_type**
#
# Chrome-->0
#
# Firefox-->1
#
# Edge-->2
#
# Unkown-->3
#
# Safari-->4

# %%
data['browser_type'] = data['browser_type'].map({'Chrome':0, 'Firefox':1, 'Edge':2, 'Unknown':3,'Safari':4})

# %% [markdown]
# **Label Encoding Encryption Used**
#
# AES-->0
#
# DES-->1

# %%
data['encryption_used']=data['encryption_used'].map({'AES':0,'DES':1})

# %%
data.head()
# Out:
#   session_id  network_packet_size  protocol_type  login_attempts  \
# 0  SID_00001                  599              0               4
# 1  SID_00002                  472              0               3
# 2  SID_00003                  629              0               3
# 3  SID_00004                  804              1               4
# 4  SID_00005                  453              0               5
#
#    session_duration  encryption_used  ip_reputation_score  failed_logins  \
# 0        492.983263              1.0             0.606818              1
# 1       1557.996461              1.0             0.301569              0
# 2         75.044262              1.0             0.739164              2
# 3        601.248835              1.0             0.123267              0
# 4        532.540888              0.0             0.054874              1
#
#    browser_type  unusual_time_access  attack_detected
# 0             2                    0                1
# ...

# %% [markdown]
# **Feature Importance**

# %%
data.drop("session_id",inplace=True,axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop('attack_detected', axis=1), data['attack_detected'], test_size=0.2, random_state=42)

# %%
rf=RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
X=data.drop("attack_detected",axis=1)

# %%
importances = rf.feature_importances_
feature_names = X.columns
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# %%
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print(feature_importance_df)
# Out:
#                Feature  Importance
# 6        failed_logins    0.283621
# 5  ip_reputation_score    0.230773
# 2       login_attempts    0.213706
# 3     session_duration    0.098756
# 0  network_packet_size    0.091548
# 7         browser_type    0.046555
# 1        protocol_type    0.013542
# 4      encryption_used    0.012645
# 8  unusual_time_access    0.008855

# %%
top_features = feature_importance_df['Feature'][:7].values
X_train_selected = X_train[top_features]
X_test_selected = X_test[top_features]

# %%
top_features
# Out:
# array(['failed_logins', 'ip_reputation_score', 'login_attempts',
#        'session_duration', 'network_packet_size', 'browser_type',
#        'protocol_type'], dtype=object)

# %% [markdown]
# #**Decision Trees Implementation**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **With all Features**

# %%
model_DT=DecisionTreeClassifier()

# %%
model_DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_DT=model_DT.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy_score_DT1=accuracy_score(y_test, y_pred_DT)
print(f"Test_accuracy of Decsion Trees with all Features:{accuracy_score_DT}")
# Out:
# Test_accuracy of Decsion Trees with all Features:0.8176100628930818

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 7, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10,15],
    'criterion': ['gini', 'entropy'],
    'class_weight': [None, 'balanced']
}

grid_search = GridSearchCV(model_DT, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'class_weight': None, 'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 2}
# Best accuracy: 0.8931717336656424

# %%
best_DT_model_full = grid_search.best_estimator_

# %%
y_pred_full = best_DT_model_full.predict(X_test)

# %%
test_accuracy_full = accuracy_score(y_test, y_pred_full)
print(f"DT_Test Accuracy: {test_accuracy_full:.4f}")
# Out:
# DT_Test Accuracy: 0.8973

# %% [markdown]
# **With Top Features**

# %%
model_top=DecisionTreeClassifier()

# %%
model_top.fit(X_train_selected, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model_top.predict(X_test_selected)

# %%
accuracy_score_DT_top=accuracy_score(y_test, y_pred)

# %%
accuracy_score_DT
# Out:
# 0.8176100628930818

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 7, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10,15],
    'criterion': ['gini', 'entropy'],
    'class_weight': [None, 'balanced']
}

grid_search_top = GridSearchCV(model_top, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search_top.fit(X_train_selected, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best accuracy:", grid_search.best_score_)
# Out:
# Best parameters: {'class_weight': None, 'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 10, 'min_samples_split': 2}
# Best accuracy: 0.8931717336656424

# %%
best_DT_model_top = grid_search_top.best_estimator_

# %%
y_pred1 = best_DT_model_top.predict(X_test_selected)

# %%
test_accuracy_top = accuracy_score(y_test, y_pred1)
print(f"Test Accuracy: {test_accuracy_top:.4f}")
# Out:
# Test Accuracy: 0.8920

# %% [markdown]
# #**Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression(max_iter=1000)

# %%
LR.fit(X_train_selected, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
LR_pred=LR.predict(X_test_selected)

# %%
LR_accuracy=accuracy_score(y_test, LR_pred)
LR_accuracy
# Out:
# 0.7358490566037735

# %% [markdown]
# #**AdaBoost**

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
Ada_Model=AdaBoostClassifier()

# %%
Ada_Model.fit(X_train_selected, y_train)
# Out:
# AdaBoostClassifier()

# %%
Ada_pred=Ada_Model.predict(X_test_selected)

# %%
Ada_accuracy=accuracy_score(y_test, Ada_pred)
Ada_accuracy
# Out:
# 0.8679245283018868

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0],
    'estimator__max_depth': [7],
    'estimator__min_samples_split':[5],
    'estimator__min_samples_leaf':[10],
    'algorithm': ['SAMME']
}

Ada_Model = AdaBoostClassifier(estimator = DecisionTreeClassifier())

grid_search_ada = GridSearchCV(
    estimator=Ada_Model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)


grid_search_ada.fit(X_train_selected, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier()),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME'], 'estimator__max_depth': [7],
#                          'estimator__min_samples_leaf': [10],
#                          'estimator__min_samples_split': [5],
#                          'learning_rate': [0.01, 0.1, 1.0],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
print("Best parameters:", grid_search_ada.best_params_)
print("Best accuracy:", grid_search_ada.best_score_)
# Out:
# Best parameters: {'algorithm': 'SAMME', 'estimator__max_depth': 7, 'estimator__min_samples_leaf': 10, 'estimator__min_samples_split': 5, 'learning_rate': 0.01, 'n_estimators': 50}
# Best accuracy: 0.8921232408740305

# %%
best_ada_model = grid_search_ada.best_estimator_

# %%
y_pred = best_ada_model.predict(X_test_selected)

# %%
test_accuracy_ada = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {test_accuracy_ada:.4f}")
# Out:
# Test Accuracy: 0.8920

# %% [markdown]
# **Comparsion of Models**

# %%
import pandas as pd

results = {
    "Model": ["Decsion Tree(Full Features)","Decision Trees(Top Features)", "Logistic Regression", "Adaboost"],
    "Accuracy(%)": [89.73, 89.31,73.54 ,89.20],
}

results_df = pd.DataFrame(results)

print(results_df)
# Out:
#                           Model  Accuracy(%)
# 0   Decsion Tree(Full Features)        89.73
# 1  Decision Trees(Top Features)        89.31
# 2           Logistic Regression        73.54
# 3                      Adaboost        89.20
